# %%
#Khai báo các thư viện cần sử dụng
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#Kết nối với google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Tạo ra class ImageDataGenerator để chỉnh sửa ảnh 
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory('/content/drive/My Drive/Colab Notebooks/BTVN/FL/Train', target_size=(224,224), batch_size=32, class_mode='categorical')
# Out:
# Found 177 images belonging to 3 classes.

# %%
# Tạo bộ dữ liệu test
test_set = train_datagen.flow_from_directory('/content/drive/My Drive/Colab Notebooks/BTVN/FL/Test', target_size=(224,224), batch_size=32, class_mode='categorical')
# Out:
# Found 18 images belonging to 3 classes.

# %%
# Các nhãn có trong bộ dữ liệu training
training_set.class_indices
# Out:
# {'Cam tu cau': 0, 'Hoa cuc': 1, 'Hoa lan': 2}

# %%
# Các nhãn có trong bộ dữ liệu test
test_set.class_indices
# Out:
# {'Cam tu cau': 0, 'Hoa cuc': 1, 'Hoa lan': 2}

# %%
x_train = np.concatenate([training_set.next()[0] for i in range(training_set.__len__())])
y_train = np.concatenate([training_set.next()[1] for i in range(training_set.__len__())])
print(x_train.shape)
print(y_train.shape)
# Out:
# (177, 224, 224, 3)
# (177, 3)

# %%
x_test = np.concatenate([test_set.next()[0] for i in range(test_set.__len__())])
y_test = np.concatenate([test_set.next()[1] for i in range(test_set.__len__())])
print(x_test.shape)
print(y_test.shape)
# Out:
# (18, 224, 224, 3)
# (18, 3)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(2048, activation = "relu", input_shape = (224*224*3,)))
model.add(layers.Dense(2048, activation= "relu"))
model.add(layers.Dense(3, activation= "softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2048)              308283392
#
#  dense_1 (Dense)             (None, 2048)              4196352
#
#  dense_2 (Dense)             (None, 3)                 6147
#
# =================================================================
# Total params: 312,485,891
# Trainable params: 312,485,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = x_train.reshape((177,224*224*3))
x_test = x_test.reshape((18,224*224*3))
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
x_train.shape
# Out:
# (177, 150528)

# %%
y_train.shape
# Out:
# (177, 3)

# %%
model.compile(optimizer="rmsprop", loss = "categorical_crossentropy", metrics=["accuracy"])
model.fit(x_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 32s 5s/step - loss: 8.5370 - accuracy: 0.3333
# Epoch 2/100
# 6/6 [==============================] - 22s 4s/step - loss: 1.3974 - accuracy: 0.3503
# Epoch 3/100
# 6/6 [==============================] - 23s 4s/step - loss: 1.1225 - accuracy: 0.3616
# Epoch 4/100
# 6/6 [==============================] - 22s 4s/step - loss: 1.1120 - accuracy: 0.3390
# Epoch 5/100
# 6/6 [==============================] - 22s 4s/step - loss: 1.1028 - accuracy: 0.3785
# Epoch 6/100
# 6/6 [==============================] - 22s 4s/step - loss: 1.1500 - accuracy: 0.4350
# Epoch 7/100
# 6/6 [==============================] - 22s 4s/step - loss: 1.1143 - accuracy: 0.4237
# Epoch 8/100
# 6/6 [==============================] - 22s 4s/step - loss: 1.1199 - accuracy: 0.4237
# Epoch 9/100
# 6/6 [==============================] - 22s 4s/step - loss: 1.0446 - accuracy: 0.4520
# Epoch 10/100
# 6/6 [==============================] - 22s 4s/step - loss: 1.0305 - accuracy: 0.4915
# Epoch 11/100
# 6/6 [==============================] - 23s 4s/step - loss: 1.1515 - accuracy: 0.3277
# Epoch 12/100
# 6/6 [==============================] - 22s 4s/step - loss: 1
100
# 6/6 [==============================] - 21s 4s/step - loss: 0.3770 - accuracy: 0.8588
# Epoch 61/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0814 - accuracy: 0.9887
# Epoch 62/100
# 6/6 [==============================] - 23s 4s/step - loss: 0.3800 - accuracy: 0.8418
# Epoch 63/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.1605 - accuracy: 0.9605
# Epoch 64/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.3186 - accuracy: 0.9096
# Epoch 65/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.5154 - accuracy: 0.7853
# Epoch 66/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.5707 - accuracy: 0.8136
# Epoch 67/100
# 6/6 [==============================] - 21s 3s/step - loss: 0.0499 - accuracy: 0.9944
# Epoch 68/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0361 - accuracy: 0.9944
# Epoch 69/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0217 - accuracy: 0.9944
# Epoch 70/100
# 6/6 [==============================] - 21s 4s/step - loss: 2.0373 - accuracy: 0.7062
# Epoch 71/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0894 - accuracy: 0.9887
# Epoch 72/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0346 - accuracy: 0.9944
# Epoch 73/100
# 6/6 [==============================] - 23s 4s/step - loss: 0.0253 - accuracy: 0.9944
# Epoch 74/100
# 6/6 [==============================] - 21s 4s/step - loss: 2.4884 - accuracy: 0.5706
# Epoch 75/100
# 6/6 [==============================] - 21s 3s/step - loss: 0.0817 - accuracy: 0.9944
# Epoch 76/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0755 - accuracy: 0.9831
# Epoch 77/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0428 - accuracy: 0.9944
# Epoch 78/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.5111 - accuracy: 0.8249
# Epoch 79/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.5220 - accuracy: 0.8757
# Epoch 80/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0492 - accuracy: 0.9944
# Epoch 81/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0373 - accuracy: 0.9944
# Epoch 82/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0312 - accuracy: 0.9944
# Epoch 83/100
# 6/6 [==============================] - 23s 4s/step - loss: 0.4026 - accuracy: 0.9209
# Epoch 84/100
# 6/6 [==============================] - 31s 5s/step - loss: 1.0777 - accuracy: 0.7175
# Epoch 85/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0507 - accuracy: 1.0000
# Epoch 86/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 87/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 88/100
# 6/6 [==============================] - 21s 4s/step - loss: 1.8226 - accuracy: 0.7119
# Epoch 89/100
# 6/6 [==============================] - 21s 3s/step - loss: 0.0659 - accuracy: 1.0000
# Epoch 90/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 91/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 92/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 93/100
# 6/6 [==============================] - 23s 4s/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 94/100
# 6/6 [==============================] - 21s 4s/step - loss: 1.5914 - accuracy: 0.6610
# Epoch 95/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0553 - accuracy: 1.0000
# Epoch 96/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 97/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 98/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 99/100
# 6/6 [==============================] - 21s 4s/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 100/100
# 6/6 [==============================] - 21s 4s/step - loss: 2.5460 - accuracy: 0.5819

# %%
# Lưu lại
model.save("Nhan_dien_hoa.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Tải mô hình 
model_ANN=load_model('Nhan_dien_hoa.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
from keras.utils import img_to_array
import numpy as np 
from keras.utils import load_img
img = load_img('Cuc (21).jpg',target_size = (224,224,3))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,224,224,3)
#img = img[:,:,0]
img = img.astype('float32')
img = img/255
img = img.reshape(-1,224*224*3)
class_names = ["Cẩm Tú Cầu", "Hoa Cúc", "Hoa Lan"]
print(model_ANN.predict(img))
print(class_names[np.argmax(model_ANN.predict(img))])
# Out:
# 1/1 [==============================] - 0s 368ms/step
# [[0.26093784 0.3913465  0.34771565]]
# 1/1 [==============================] - 0s 273ms/step
# Hoa Cúc
